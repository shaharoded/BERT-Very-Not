# %%
import pickle
from collections import defaultdict

# Replace with the actual path
file_path = 'snli_mnli_llm_train.pkl'
with open(file_path, 'rb') as f:
    data = pickle.load(f)

# 2. Group by premise
by_premise = defaultdict(list)
for ex in data:
    by_premise[ex['premise']].append(ex)

# 3. Find the first two premises that have both an entailment and a contradiction
pairs = []
for premise, exs in by_premise.items():
    ents = [e for e in exs if e['label'] == 0]   # entailments
    cons = [e for e in exs if e['label'] == 2]   # contradictions
    if ents and cons:
        pairs.append((ents[0], cons[0]))
    if len(pairs) == 50:
        break

# 4. Print them
for idx, (orig, aug) in enumerate(pairs, 1):
    print(f"\nPair {idx}:")
    print("Original (Entailment):")
    print(f"  Premise:    {orig['premise']}")
    print(f"  Hypothesis: {orig['hypothesis']}")
    print(f"  Label:      {orig['label']}")
    print("\nAugmented (Contradiction):")
    print(f"  Premise:    {aug['premise']}")
    print(f"  Hypothesis: {aug['hypothesis']}")
    print(f"  Label:      {aug['label']}")
# Out:
# Pair 1:
# Original (Entailment):
#   Premise:    A truck on a mound of dirt is backed up to a lake.
#   Hypothesis: A truck backed up to the lake.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A truck on a mound of dirt is backed up to a lake.
#   Hypothesis: A truck is parked far away from the lake.
#   Label:      2
#
# Pair 2:
# Original (Entailment):
#   Premise:    A woman in a sky-blue shirt faces an older man wearing a navy cap.
#   Hypothesis: A woman and man are standing near each other.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A woman in a sky-blue shirt faces an older man wearing a navy cap.
#   Hypothesis: A woman in a sky-blue shirt is standing far away from an older man wearing a navy cap.
#   Label:      2
#
# Pair 3:
# Original (Entailment):
#   Premise:    An elderly person holds a white doge and kisses their cheek.
#   Hypothesis: The person is showing affection towards the dog.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    An elderly person holds a white doge and kisses their cheek.
#   Hypothesis: The cat likes to be left alone.
#   Label:      2
#
# Pair 4:
# Original (Entailment):
#   Premise:    If there was any doubt that sugar was king in those days, the Treaty of Paris (1763) dispelled  France elected to take back her little West Indian islands and leave the  few snowy acres  of Canada to the British.
#   Hypothesis: France gave some Canadian land to the British.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    If there was any doubt that sugar was king in those days, the Treaty of Paris (1763) dispelled  France elected to take back her little West Indian islands and leave the  few snowy acres  of Canada to the British.
#   Hypothesis: France retained all of her Canadian land and chose to give up her West Indian islands to the British.
#   Label:      2
#
# Pair 5:
# Original (Entailment):
#   Premise:    um-hum oh that's good any other problems
#   Hypothesis: Are there other problems?
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    um-hum oh that's good any other problems
#   Hypothesis: There are no other problems.
#   Label:      2
#
# Pair 6:
# Original (Entailment):
#   Premise:    Group of teen males picking up garbage.
#   Hypothesis: A group of teen male workers taking garbage outside.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Group of teen males picking up garbage.
#   Hypothesis: Hypothesis: A group of teen males is leaving garbage behind.
#   Label:      2
#
# Pair 7:
# Original (Entailment):
#   Premise:    Woman with bike and man with soda being in a park.
#   Hypothesis: Humans in a park
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Woman with bike and man with soda being in a park.
#   Hypothesis: Hypothesis: No one is in the park.
#   Label:      2
#
# Pair 8:
# Original (Entailment):
#   Premise:    A man and two young boys are sitting on a rock.
#   Hypothesis: The rock is occupied.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A man and two young boys are sitting on a rock.
#   Hypothesis: The people are all females.
#   Label:      2
#
# Pair 9:
# Original (Entailment):
#   Premise:    A group of construction workers wearing hard hats are standing, holding gloves and tools.
#   Hypothesis: People are standing.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A group of construction workers wearing hard hats are standing, holding gloves and tools.
#   Hypothesis: Hypothesis: No one is standing.
#   Label:      2
#
# Pair 10:
# Original (Entailment):
#   Premise:    Chubby boys raise their hands in the air while playing a sport.
#   Hypothesis: The boys are playing a sport together.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Chubby boys raise their hands in the air while playing a sport.
#   Hypothesis: The skinny kids are running around and playing a game.
#   Label:      2
#
# Pair 11:
# Original (Entailment):
#   Premise:    Two children and a woman working on a project.
#   Hypothesis: Mom helps kids with schoolwork.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Two children and a woman working on a project.
#   Hypothesis: A dog and cat learn how to do a school project.
#   Label:      2
#
# Pair 12:
# Original (Entailment):
#   Premise:    A man performing dangerous construction work.
#   Hypothesis: A person is working.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A man performing dangerous construction work.
#   Hypothesis: A construction worker is at lunch.
#   Label:      2
#
# Pair 13:
# Original (Entailment):
#   Premise:    A man in a red shirt is sitting by fruit for sale.
#   Hypothesis: The fruits are on display for people to buy.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A man in a red shirt is sitting by fruit for sale.
#   Hypothesis: A man in a blue shirt is sitting far away from the fruit for sale.
#   Label:      2
#
# Pair 14:
# Original (Entailment):
#   Premise:    well not i didn't say New England but i could definitely tell your from the north
#   Hypothesis: I didn't think you were from New England.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    well not i didn't say New England but i could definitely tell your from the north
#   Hypothesis: I actually thought you were from New England.
#   Label:      2
#
# Pair 15:
# Original (Entailment):
#   Premise:    Or is bandwidth abuse a real moral question?
#   Hypothesis: Is the misuse of bandwidth a genuine moral question?
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Or is bandwidth abuse a real moral question?
#   Hypothesis: The misuse of bandwidth is not a genuine moral question at all.
#   Label:      2
#
# Pair 16:
# Original (Entailment):
#   Premise:    Two girls walk through a tunnel with red and yellow items that they pull through the air.
#   Hypothesis: The girls are walking through the tunnel
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Two girls walk through a tunnel with red and yellow items that they pull through the air.
#   Hypothesis: The girls are not walking through the tunnel.
#   Label:      2
#
# Pair 17:
# Original (Entailment):
#   Premise:    i i like our benefits
#   Hypothesis: I enjoy our benefits.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    i i like our benefits
#   Hypothesis: I dislike our benefits.
#   Label:      2
#
# Pair 18:
# Original (Entailment):
#   Premise:    A group of people hold on as they ride on public transportation.
#   Hypothesis: The group of people are in holding on inside the vehicle.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A group of people hold on as they ride on public transportation.
#   Hypothesis: The people are renting a car.
#   Label:      2
#
# Pair 19:
# Original (Entailment):
#   Premise:    But pomposity is a perfectly legitimate cultural style.
#   Hypothesis: There exist cultural styles which can be judged as being legitimate or not.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    But pomposity is a perfectly legitimate cultural style.
#   Hypothesis: Pomposity is an illegitimate cultural style according to some criteria.
#   Label:      2
#
# Pair 20:
# Original (Entailment):
#   Premise:    A construction worker in jeans is climbing scaffolding.
#   Hypothesis: A construction worker on site making his way upwards.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A construction worker in jeans is climbing scaffolding.
#   Hypothesis: A construction worker in jeans is standing still on the ground, not climbing the scaffolding.
#   Label:      2
#
# Pair 21:
# Original (Entailment):
#   Premise:    People with a dog hike up a green mountain.
#   Hypothesis: The people and their dog go up the mountain.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    People with a dog hike up a green mountain.
#   Hypothesis: People with a dog are climbing down the mountain.
#   Label:      2
#
# Pair 22:
# Original (Entailment):
#   Premise:    I'm sorry, said the Industrialist, apologetically, "but I think I had better take care of her.
#   Hypothesis: The Industrialist wanted to take care of her.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    I'm sorry, said the Industrialist, apologetically, "but I think I had better take care of her.
#   Hypothesis: The Industrialist was not interested in taking care of her.
#   Label:      2
#
# Pair 23:
# Original (Entailment):
#   Premise:    is it all um is there any place at all where you do get cash for this stuff or is it all
#   Hypothesis: is there a place where you can trade these things for money
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    is it all um is there any place at all where you do get cash for this stuff or is it all
#   Hypothesis: There is no place where you can trade these things for money.
#   Label:      2
#
# Pair 24:
# Original (Entailment):
#   Premise:    Organizations relied on both internally and externally developed and presented training courses, sometimes engaging contractors or others to assist.
#   Hypothesis: Organizations sometimes engaged contractors.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Organizations relied on both internally and externally developed and presented training courses, sometimes engaging contractors or others to assist.
#   Hypothesis: Contractors were never engaged.
#   Label:      2
#
# Pair 25:
# Original (Entailment):
#   Premise:    A. DeConcini Federal Courthouse, 405 W. Congress St. Deconcini was one of the organization's early board members.
#   Hypothesis: Deconcini was a board member.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A. DeConcini Federal Courthouse, 405 W. Congress St. Deconcini was one of the organization's early board members.
#   Hypothesis: DeConcini was never a board member of the organization.
#   Label:      2
#
# Pair 26:
# Original (Entailment):
#   Premise:    A group of people are walking through a bunch of leaves.
#   Hypothesis: A group of people are walking.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A group of people are walking through a bunch of leaves.
#   Hypothesis: A group of people are shoveling snow.
#   Label:      2
#
# Pair 27:
# Original (Entailment):
#   Premise:    Lighthouse in a wooded area sits above tree's.
#   Hypothesis: There is a building in this picture.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Lighthouse in a wooded area sits above tree's.
#   Hypothesis: There is no building in this picture.
#   Label:      2
#
# Pair 28:
# Original (Entailment):
#   Premise:    A young child sits in a highchair and draws colorful squiggles on a white piece of paper.
#   Hypothesis: A kid is drawing something.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A young child sits in a highchair and draws colorful squiggles on a white piece of paper.
#   Hypothesis: A boy is fighting with his sibling.
#   Label:      2
#
# Pair 29:
# Original (Entailment):
#   Premise:    Two ballet dancers, one wearing white and one wearing green, dancing on a stage.
#   Hypothesis: The dancers dance on stage.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Two ballet dancers, one wearing white and one wearing green, dancing on a stage.
#   Hypothesis: The dancers fell off the stage.
#   Label:      2
#
# Pair 30:
# Original (Entailment):
#   Premise:    (2) how should the federal government do business in the 21st century?
#   Hypothesis: How should the federal government operate in the 21st century?
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    (2) how should the federal government do business in the 21st century?
#   Hypothesis: The federal government should not change its business practices for the 21st century.
#   Label:      2
#
# Pair 31:
# Original (Entailment):
#   Premise:    A group of men are at a bar having drinks.
#   Hypothesis: There are drinks being consumed at the bar.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A group of men are at a bar having drinks.
#   Hypothesis: The group of men were at the cemetery.
#   Label:      2
#
# Pair 32:
# Original (Entailment):
#   Premise:    Hannah was recently spotted in New York wearing a hat with a star on it, while Kennedy was photographed elsewhere in the Big Apple wearing a T-shirt with--are you sitting down?
#   Hypothesis: Are you sitting down?  While Hannah was recently spotted wearing a hat with a star on it, Kennedy was spotted wearing a T-Shirt with...
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Hannah was recently spotted in New York wearing a hat with a star on it, while Kennedy was photographed elsewhere in the Big Apple wearing a T-shirt with--are you sitting down?
#   Hypothesis: In New York Hannah was spotted wearing a hat that contained profanity.
#   Label:      2
#
# Pair 33:
# Original (Entailment):
#   Premise:    A shirtless man traveling down river in a paddle boat.
#   Hypothesis: There is a boat on the river.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A shirtless man traveling down river in a paddle boat.
#   Hypothesis: The man is walking next to the river.
#   Label:      2
#
# Pair 34:
# Original (Entailment):
#   Premise:    Triathlete biking around a corner.
#   Hypothesis: A triathlete is taking a bike ride.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Triathlete biking around a corner.
#   Hypothesis: A triathlete is not biking around a corner.
#   Label:      2
#
# Pair 35:
# Original (Entailment):
#   Premise:    A teenage boy jumping over a railing.
#   Hypothesis: A teenager jumps over the railing.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A teenage boy jumping over a railing.
#   Hypothesis: A teenage boy is standing still and not jumping over the railing.
#   Label:      2
#
# Pair 36:
# Original (Entailment):
#   Premise:    A girl jumps in the grass.
#   Hypothesis: The grass absorbs a child leaping vertically.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A girl jumps in the grass.
#   Hypothesis: A little girl is sitting indoors.
#   Label:      2
#
# Pair 37:
# Original (Entailment):
#   Premise:    A woman in a dress is on stage performing before an audience while someone plays a keyboard in the background.
#   Hypothesis: A woman in a dress is performing before an audience while someone plays a keyboard in the background.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A woman in a dress is on stage performing before an audience while someone plays a keyboard in the background.
#   Hypothesis: A woman in a dress is not performing before an audience, and there is no one playing a keyboard in the background.
#   Label:      2
#
# Pair 38:
# Original (Entailment):
#   Premise:    A woman in a blue dress sings while her bandmates play instruments.
#   Hypothesis: People are singing and playing instruments.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A woman in a blue dress sings while her bandmates play instruments.
#   Hypothesis: The singing woman is wearing a green dress.
#   Label:      2
#
# Pair 39:
# Original (Entailment):
#   Premise:    A man trains his body pulling a keg.
#   Hypothesis: A man pulling something large.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A man trains his body pulling a keg.
#   Hypothesis: A man sits down in his rocking chair, smoking a pipe.
#   Label:      2
#
# Pair 40:
# Original (Entailment):
#   Premise:    Two men wearing white boxing gloves are in a ring.
#   Hypothesis: Two males in a boxing ring.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Two men wearing white boxing gloves are in a ring.
#   Hypothesis: Two men are not in a boxing ring.
#   Label:      2
#
# Pair 41:
# Original (Entailment):
#   Premise:    a small black dog biting a ladies two fingers on a beige couch
#   Hypothesis: A woman is being bit by a dog
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    a small black dog biting a ladies two fingers on a beige couch
#   Hypothesis: The dog is white
#   Label:      2
#
# Pair 42:
# Original (Entailment):
#   Premise:    Two men in baseball hats selling asparagus and other vegetables from an outdoor stand to a woman carrying a green bag.
#   Hypothesis: Two men sell vegetables at an outdoor stand.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Two men in baseball hats selling asparagus and other vegetables from an outdoor stand to a woman carrying a green bag.
#   Hypothesis: The men are selling home made cheese and butter.
#   Label:      2
#
# Pair 43:
# Original (Entailment):
#   Premise:    Three human carriages that are not in service, two of them being used by barefoot men for shade on a hot day.
#   Hypothesis: There are three carriages.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Three human carriages that are not in service, two of them being used by barefoot men for shade on a hot day.
#   Hypothesis: There are six carrriages.
#   Label:      2
#
# Pair 44:
# Original (Entailment):
#   Premise:    Two little boys reading and looking at books on the stairs.
#   Hypothesis: Children have books to read inside.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Two little boys reading and looking at books on the stairs.
#   Hypothesis: Adults are playing on their iPhones.
#   Label:      2
#
# Pair 45:
# Original (Entailment):
#   Premise:    A lady in a black and white striped shirt and holding a bouquet of flowers, looks seriously at two gentlemen talking on the steps.
#   Hypothesis: A lady with a serious face is standing with two guys in front of steps outside.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A lady in a black and white striped shirt and holding a bouquet of flowers, looks seriously at two gentlemen talking on the steps.
#   Hypothesis: Three guys are standing indoors with flowers in their hands.
#   Label:      2
#
# Pair 46:
# Original (Entailment):
#   Premise:    Two woman playing a frisbee game, the frisbee in the air about to be caught by one of the women.
#   Hypothesis: Two woman playing games
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    Two woman playing a frisbee game, the frisbee in the air about to be caught by one of the women.
#   Hypothesis: Two women are not playing frisbee at all.
#   Label:      2
#
# Pair 47:
# Original (Entailment):
#   Premise:    English class with the boys.
#   Hypothesis: A class of people.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    English class with the boys.
#   Hypothesis: A women-only sewing circle shows their latest quilt.
#   Label:      2
#
# Pair 48:
# Original (Entailment):
#   Premise:    It is not a reward for the criminal but a punishment for the prosecutor.
#   Hypothesis: It's not a reward for the criminal; it is punishment for their prosecutor.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    It is not a reward for the criminal but a punishment for the prosecutor.
#   Hypothesis: It is a reward for the criminal, not a punishment for the prosecutor.
#   Label:      2
#
# Pair 49:
# Original (Entailment):
#   Premise:    A man in a white shirt is holding a broom in the middle of a street
#   Hypothesis: There is a man in a white shirt holding a broom.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A man in a white shirt is holding a broom in the middle of a street
#   Hypothesis: There is no man in a white shirt holding a broom.
#   Label:      2
#
# Pair 50:
# Original (Entailment):
#   Premise:    A band is playing in a concert.
#   Hypothesis: People playing a concert.
#   Label:      0
#
# Augmented (Contradiction):
#   Premise:    A band is playing in a concert.
#   Hypothesis: Hypothesis: No one is performing at the concert.
#   Label:      2

# %%
import pickle
from collections import defaultdict

# Load data
file_path = 'snli_mnli_squad_spacy_validation.pkl'
with open(file_path, 'rb') as f:
    data = pickle.load(f)

# Step 1: Index all entailments by premise
entailments = defaultdict(list)
for ex in data:
    if ex['label'] == 0:
        entailments[ex['premise']].append(ex)

# Step 2: Find contradictions from SQuAD-style augmentation
spacy_contradictions = []
for ex in data:
    if ex['label'] == 2:
        # Only keep if there’s a matching entailment for the same premise
        if ex['premise'] in entailments:
            spacy_contradictions.append((entailments[ex['premise']][0], ex))

# Step 3: Take the last 50
print(f"Found {len(spacy_contradictions)} contradiction pairs with matched entailments.")
last_50 = spacy_contradictions[-50:]

# Step 4: Print the results
for idx, (ent, contra) in enumerate(last_50, start=1):
    print(f"\nPair {idx}:")
    print("Original (Entailment):")
    print(f"  Premise:    {ent['premise']}")
    print(f"  Hypothesis: {ent['hypothesis']}")
    print(f"  Label:      {ent['label']}")
    print("Augmented (Contradiction):")
    print(f"  Premise:    {contra['premise']}")
    print(f"  Hypothesis: {contra['hypothesis']}")
    print(f"  Label:      {contra['label']}")
# Out:
# Found 10263 contradiction pairs with matched entailments.
#
# Pair 1:
# Original (Entailment):
#   Premise:    Since the 1980s, Lutheran Church denominations have repudiated Martin Luther's statements against the Jews and have rejected the use of them to incite hatred against Lutherans. Strommen et al.'s 1970 survey of 4,745 North American Lutherans aged 15–65 found that, compared to the other minority groups under consideration, Lutherans were the least prejudiced toward Jews. Nevertheless, Professor Richard (Dick) Geary, former Professor of Modern History at the University of Nottingham, England, and the author of Hitler and Nazism (Routledge 1993), wrote in the journal History Today an article on who voted for the Nazis in elections held from 1928-1933, where he claimed that from his research he found that the Nazis gained disproportionately more votes from Protestant than Catholic areas of Germany.
#   Hypothesis: When were the elections that produced a higher vote by Protestant Nazi sympathizers than by Catholics?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Since the 1980s, Lutheran Church denominations have repudiated Martin Luther's statements against the Jews and have rejected the use of them to incite hatred against Lutherans. Strommen et al.'s 1970 survey of 4,745 North American Lutherans aged 15–65 found that, compared to the other minority groups under consideration, Lutherans were the least prejudiced toward Jews. Nevertheless, Professor Richard (Dick) Geary, former Professor of Modern History at the University of Nottingham, England, and the author of Hitler and Nazism (Routledge 1993), wrote in the journal History Today an article on who voted for the Nazis in elections held from 1928-1933, where he claimed that from his research he found that the Nazis gained disproportionately more votes from Protestant than Catholic areas of Germany.
#   Hypothesis: Who found that Protestants voted for UN more than Catholics?
#   Label:      2
#
# Pair 2:
# Original (Entailment):
#   Premise:    The public health official's version of the line, Take my wife, please, is Tell Americans to eat kale five times a week.
#   Hypothesis: Public health authorities believe that people should eat kale many times a week.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    The public health official's version of the line, Take my wife, please, is Tell Americans to eat kale five times a week.
#   Hypothesis: Public health officials believes that Americans should avoid kale in their diet completely.
#   Label:      2
#
# Pair 3:
# Original (Entailment):
#   Premise:    North American Aviation won the contract to build the CSM, and also the second stage of the Saturn V launch vehicle for NASA. Because the CSM design was started early before the selection of lunar orbit rendezvous, the service propulsion engine was sized to lift the CSM off of the Moon, and thus was oversized to about twice the thrust required for translunar flight. Also, there was no provision for docking with the Lunar Module. A 1964 program definition study concluded that the initial design should be continued as Block I which would be used for early testing, while Block II, the actual lunar spacecraft, would incorporate the docking equipment and take advantage of the lessons learned in Block I development.
#   Hypothesis: How much thrust was estimated for the translunar flight?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    North American Aviation won the contract to build the CSM, and also the second stage of the Saturn V launch vehicle for NASA. Because the CSM design was started early before the selection of lunar orbit rendezvous, the service propulsion engine was sized to lift the CSM off of the Moon, and thus was oversized to about twice the thrust required for translunar flight. Also, there was no provision for docking with the Lunar Module. A 1964 program definition study concluded that the initial design should be continued as Block I which would be used for early testing, while Block II, the actual lunar spacecraft, would incorporate the docking equipment and take advantage of the lessons learned in Block I development.
#   Hypothesis: What was the name of the launch vehicle for NASA, which UN designed the second stage of?
#   Label:      2
#
# Pair 4:
# Original (Entailment):
#   Premise:    All of ABC's owned-and-operated stations and affiliates have had their own facilities and studios, but transverse entities have been created to produce national programming. As a result, television series were produced by ABC Circle Films beginning in 1962 and by Touchstone Television beginning in 1985, before Touchstone was reorganized as ABC Studios in February 2007. Since the 1950s, ABC has had two main production facilities: the ABC Television Center (now The Prospect Studios) on Prospect Avenue in Hollywood, California, shared with the operations of KABC-TV until 1999; and the ABC Television Center, East, a set of studios located throughout the New York City.
#   Hypothesis: Which of ABC's main production facilities is located in New York City?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    All of ABC's owned-and-operated stations and affiliates have had their own facilities and studios, but transverse entities have been created to produce national programming. As a result, television series were produced by ABC Circle Films beginning in 1962 and by Touchstone Television beginning in 1985, before Touchstone was reorganized as ABC Studios in February 2007. Since the 1950s, ABC has had two main production facilities: the ABC Television Center (now The Prospect Studios) on Prospect Avenue in Hollywood, California, shared with the operations of KABC-TV until 1999; and the ABC Television Center, East, a set of studios located throughout the New York City.
#   Hypothesis: What entity was Apple reorganized into in 2007?
#   Label:      2
#
# Pair 5:
# Original (Entailment):
#   Premise:    In the spring of 1975, Fred Pierce, the newly appointed president of ABC Television, convinced Fred Silverman to become the first president and director of programming of the independent television production subsidiary ABC Entertainment, created from the network's namesake programming division. In 1974, ABC premiered the detective series S.W.A.T. That same year, the network made the decision to compete with NBC's morning news-talk program Today. Its first attempt at such competition was AM America; however, that show's success was not straightforward. One of its affiliates, WCVB-TV premiered morning show Good Day!. First premiering in 1973 as Good Morning!, it was groundbreaking for being entirely produced on the road and broadcasting from locations outside of the Boston area. Also, in the summer of 1975, ABC discovered that its Cleveland affiliate WEWS-TV was producing its own morning program The Morning Exchange, which debuted in 1972 and was now locally pre-empting AM America; it was the first morning show to utilize a set modeled after a living room, and established a concept now commonplace among network morning shows in which news and weather updates were featured at the top and bottom of each hour. Discovering that their formats seemed to appeal to their viewers, the network became the first to adopt them for a new national morning show, Good Morning America, which debuted on November 3, 1975.
#   Hypothesis: When did Good Morning America first debut?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    In the spring of 1975, Fred Pierce, the newly appointed president of ABC Television, convinced Fred Silverman to become the first president and director of programming of the independent television production subsidiary ABC Entertainment, created from the network's namesake programming division. In 1974, ABC premiered the detective series S.W.A.T. That same year, the network made the decision to compete with NBC's morning news-talk program Today. Its first attempt at such competition was AM America; however, that show's success was not straightforward. One of its affiliates, WCVB-TV premiered morning show Good Day!. First premiering in 1973 as Good Morning!, it was groundbreaking for being entirely produced on the road and broadcasting from locations outside of the Boston area. Also, in the summer of 1975, ABC discovered that its Cleveland affiliate WEWS-TV was producing its own morning program The Morning Exchange, which debuted in 1972 and was now locally pre-empting AM America; it was the first morning show to utilize a set modeled after a living room, and established a concept now commonplace among network morning shows in which news and weather updates were featured at the top and bottom of each hour. Discovering that their formats seemed to appeal to their viewers, the network became the first to adopt them for a new national morning show, Good Morning America, which debuted on November 3, 1975.
#   Hypothesis: In not 1974, what detective series debuted on ABC?
#   Label:      2
#
# Pair 6:
# Original (Entailment):
#   Premise:    After the German Invasion of Poland on 1 September 1939 began the Second World War, Warsaw was defended till September 27. Central Poland, including Warsaw, came under the rule of the General Government, a German Nazi colonial administration. All higher education institutions were immediately closed and Warsaw's entire Jewish population – several hundred thousand, some 30% of the city – herded into the Warsaw Ghetto. The city would become the centre of urban resistance to Nazi rule in occupied Europe. When the order came to annihilate the ghetto as part of Hitler's "Final Solution" on 19 April 1943, Jewish fighters launched the Warsaw Ghetto Uprising. Despite being heavily outgunned and outnumbered, the Ghetto held out for almost a month. When the fighting ended, almost all survivors were massacred, with only a few managing to escape or hide.
#   Hypothesis: How long were the fighters of the Warsaw Ghetto Uprising able to hold out?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    After the German Invasion of Poland on 1 September 1939 began the Second World War, Warsaw was defended till September 27. Central Poland, including Warsaw, came under the rule of the General Government, a German Nazi colonial administration. All higher education institutions were immediately closed and Warsaw's entire Jewish population – several hundred thousand, some 30% of the city – herded into the Warsaw Ghetto. The city would become the centre of urban resistance to Nazi rule in occupied Europe. When the order came to annihilate the ghetto as part of Hitler's "Final Solution" on 19 April 1943, Jewish fighters launched the Warsaw Ghetto Uprising. Despite being heavily outgunned and outnumbered, the Ghetto held out for almost a month. When the fighting ended, almost all survivors were massacred, with only a few managing to escape or hide.
#   Hypothesis: How much of Paris's population was Jewish?
#   Label:      2
#
# Pair 7:
# Original (Entailment):
#   Premise:    To avoid confusing or upsetting the people, Luther avoided extreme change. He also did not wish to replace one controlling system with another. He concentrated on the church in the Electorate of Saxony, acting only as an adviser to churches in new territories, many of which followed his Saxon model. He worked closely with the new elector, John the Steadfast, to whom he turned for secular leadership and funds on behalf of a church largely shorn of its assets and income after the break with Rome. For Luther's biographer Martin Brecht, this partnership "was the beginning of a questionable and originally unintended development towards a church government under the temporal sovereign". The elector authorised a visitation of the church, a power formerly exercised by bishops. At times, Luther's practical reforms fell short of his earlier radical pronouncements. For example, the Instructions for the Visitors of Parish Pastors in Electoral Saxony (1528), drafted by Melanchthon with Luther's approval, stressed the role of repentance in the forgiveness of sins, despite Luther's position that faith alone ensures justification. The Eisleben reformer Johannes Agricola challenged this compromise, and Luther condemned him for teaching that faith is separate from works. The Instruction is a problematic document for those seeking a consistent evolution in Luther's thought and practice.
#   Hypothesis: What unintended development did the relationship with the elector have on church government?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    To avoid confusing or upsetting the people, Luther avoided extreme change. He also did not wish to replace one controlling system with another. He concentrated on the church in the Electorate of Saxony, acting only as an adviser to churches in new territories, many of which followed his Saxon model. He worked closely with the new elector, John the Steadfast, to whom he turned for secular leadership and funds on behalf of a church largely shorn of its assets and income after the break with Rome. For Luther's biographer Martin Brecht, this partnership "was the beginning of a questionable and originally unintended development towards a church government under the temporal sovereign". The elector authorised a visitation of the church, a power formerly exercised by bishops. At times, Luther's practical reforms fell short of his earlier radical pronouncements. For example, the Instructions for the Visitors of Parish Pastors in Electoral Saxony (1528), drafted by Melanchthon with Luther's approval, stressed the role of repentance in the forgiveness of sins, despite Luther's position that faith alone ensures justification. The Eisleben reformer Johannes Agricola challenged this compromise, and Luther condemned him for teaching that faith is separate from works. The Instruction is a problematic document for those seeking a consistent evolution in Luther's thought and practice.
#   Hypothesis: Where was not Luther mostly concentrating his efforts on reform?
#   Label:      2
#
# Pair 8:
# Original (Entailment):
#   Premise:    Tesla was the fourth of five children. He had an older brother named Dane and three sisters, Milka, Angelina and Marica. Dane was killed in a horse-riding accident when Nikola was five. In 1861, Tesla attended the "Lower" or "Primary" School in Smiljan where he studied German, arithmetic, and religion. In 1862, the Tesla family moved to Gospić, Austrian Empire, where Tesla's father worked as a pastor. Nikola completed "Lower" or "Primary" School, followed by the "Lower Real Gymnasium" or "Normal School."
#   Hypothesis: In what year did Tesla's family move to Gospic?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Tesla was the fourth of five children. He had an older brother named Dane and three sisters, Milka, Angelina and Marica. Dane was killed in a horse-riding accident when Nikola was five. In 1861, Tesla attended the "Lower" or "Primary" School in Smiljan where he studied German, arithmetic, and religion. In 1862, the Tesla family moved to Gospić, Austrian Empire, where Tesla's father worked as a pastor. Nikola completed "Lower" or "Primary" School, followed by the "Lower Real Gymnasium" or "Normal School."
#   Hypothesis: What job did not Tesla's father have in Gospic?
#   Label:      2
#
# Pair 9:
# Original (Entailment):
#   Premise:    The standard technology assumptions of scenario A were used by EIA in the development of the AEO2001 reference case projections.
#   Hypothesis: EIA used the standard technology assumptions to develop the AEO2001 reference case projections.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    The standard technology assumptions of scenario A were used by EIA in the development of the AEO2001 reference case projections.
#   Hypothesis: EIA used the standard technology assumptions to eliminate the AEO2001 reference case projections.
#   Label:      2
#
# Pair 10:
# Original (Entailment):
#   Premise:    Administrator Webb realized that in order to keep Apollo costs under control, he had to develop greater project management skills in his organization, so he recruited Dr. George E. Mueller for a high management job. Mueller accepted, on the condition that he have a say in NASA reorganization necessary to effectively administer Apollo. Webb then worked with Associate Administrator (later Deputy Administrator) Robert Seamans to reorganize the Office of Manned Space Flight (OMSF). On July 23, 1963, Webb announced Mueller's appointment as Deputy Associate Administrator for Manned Space Flight, to replace then Associate Administrator D. Brainerd Holmes on his retirement effective September 1. Under Webb's reorganization, the directors of the Manned Spacecraft Center (Gilruth) Marshall Space Flight Center (von Braun) and the Launch Operations Center (Debus) effectively reported to Mueller.
#   Hypothesis: Who was Mueller replaced as Associate Administrator?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Administrator Webb realized that in order to keep Apollo costs under control, he had to develop greater project management skills in his organization, so he recruited Dr. George E. Mueller for a high management job. Mueller accepted, on the condition that he have a say in NASA reorganization necessary to effectively administer Apollo. Webb then worked with Associate Administrator (later Deputy Administrator) Robert Seamans to reorganize the Office of Manned Space Flight (OMSF). On July 23, 1963, Webb announced Mueller's appointment as Deputy Associate Administrator for Manned Space Flight, to replace then Associate Administrator D. Brainerd Holmes on his retirement effective September 1. Under Webb's reorganization, the directors of the Manned Spacecraft Center (Gilruth) Marshall Space Flight Center (von Braun) and the Launch Operations Center (Debus) effectively reported to Mueller.
#   Hypothesis: When was Mueller announced and appointed as Deputy not Associate Administrator?
#   Label:      2
#
# Pair 11:
# Original (Entailment):
#   Premise:    A number of Huguenots served as mayors in Dublin, Cork, Youghal and Waterford in the 17th and 18th centuries. Numerous signs of Huguenot presence can still be seen with names still in use, and with areas of the main towns and cities named after the people who settled there. Examples include the Huguenot District and French Church Street in Cork City; and D'Olier Street in Dublin, named after a High Sheriff and one of the founders of the Bank of Ireland. A French church in Portarlington dates back to 1696, and was built to serve the significant new Huguenot community in the town. At the time, they constituted the majority of the townspeople.
#   Hypothesis: D'Olier Street is named after whom?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    A number of Huguenots served as mayors in Dublin, Cork, Youghal and Waterford in the 17th and 18th centuries. Numerous signs of Huguenot presence can still be seen with names still in use, and with areas of the main towns and cities named after the people who settled there. Examples include the Huguenot District and French Church Street in Cork City; and D'Olier Street in Dublin, named after a High Sheriff and one of the founders of the Bank of Ireland. A French church in Portarlington dates back to 1696, and was built to serve the significant new Huguenot community in the town. At the time, they constituted the majority of the townspeople.
#   Hypothesis: The French church in not Portarlington was built when?
#   Label:      2
#
# Pair 12:
# Original (Entailment):
#   Premise:    On October 6, 1973, Syria and Egypt, with support from other Arab nations, launched a surprise attack on Israel, on Yom Kippur. This renewal of hostilities in the Arab–Israeli conflict released the underlying economic pressure on oil prices. At the time, Iran was the world's second-largest oil exporter and a close US ally. Weeks later, the Shah of Iran said in an interview: "Of course [the price of oil] is going to rise... Certainly! And how!... You've [Western nations] increased the price of the wheat you sell us by 300 percent, and the same for sugar and cement... You buy our crude oil and sell it back to us, refined as petrochemicals, at a hundred times the price you've paid us... It's only fair that, from now on, you should pay more for oil. Let's say ten times more."
#   Hypothesis: When did Syria and Egypt launch a surprise attack on Israel?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    On October 6, 1973, Syria and Egypt, with support from other Arab nations, launched a surprise attack on Israel, on Yom Kippur. This renewal of hostilities in the Arab–Israeli conflict released the underlying economic pressure on oil prices. At the time, Iran was the world's second-largest oil exporter and a close US ally. Weeks later, the Shah of Iran said in an interview: "Of course [the price of oil] is going to rise... Certainly! And how!... You've [Western nations] increased the price of the wheat you sell us by 300 percent, and the same for sugar and cement... You buy our crude oil and sell it back to us, refined as petrochemicals, at a hundred times the price you've paid us... It's only fair that, from now on, you should pay more for oil. Let's say ten times more."
#   Hypothesis: Why did the Shah of New York gave an interview?
#   Label:      2
#
# Pair 13:
# Original (Entailment):
#   Premise:    Territorial rights, in the form of a deck chair, can be assured for a nominal sum.
#   Hypothesis: A deck chair can be used to show territorial rights.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Territorial rights, in the form of a deck chair, can be assured for a nominal sum.
#   Hypothesis: You have no territorial rights with a deck chair.
#   Label:      2
#
# Pair 14:
# Original (Entailment):
#   Premise:    By 1954, all U.S. networks had regained control of their programming, with higher advertising revenues: ABC's revenue increased by 67% (earning $26 million), NBC's went up by 30% ($100 million) and CBS's rose by 44% ($117 million). However that year, ABC had only 14 primary affiliates compared to the 74 that carried the majority of CBS programs and the 71 that were primarily affiliated with NBC. Most markets outside the largest ones were not large enough to support three full-time network affiliates. In some markets that were large enough for a third full-time affiliate, the only available commercial allocation was on the less-desirable UHF band. Until the All-Channel Receiver Act (passed by Congress in 1961) mandated the inclusion of UHF tuning, most viewers needed to purchase a converter to be able to watch UHF stations, and the signal quality was marginal at best even with a converter. Additionally, during the analog television era, UHF stations were not adequately receivable in rugged terrain. These factors made many prospective station owners skittish about investing in a UHF station, especially one that would have had to take on an affiliation with a weaker network.
#   Hypothesis: The All-Channel Receiver Act mandated the support of what kind of tuning?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    By 1954, all U.S. networks had regained control of their programming, with higher advertising revenues: ABC's revenue increased by 67% (earning $26 million), NBC's went up by 30% ($100 million) and CBS's rose by 44% ($117 million). However that year, ABC had only 14 primary affiliates compared to the 74 that carried the majority of CBS programs and the 71 that were primarily affiliated with NBC. Most markets outside the largest ones were not large enough to support three full-time network affiliates. In some markets that were large enough for a third full-time affiliate, the only available commercial allocation was on the less-desirable UHF band. Until the All-Channel Receiver Act (passed by Congress in 1961) mandated the inclusion of UHF tuning, most viewers needed to purchase a converter to be able to watch UHF stations, and the signal quality was marginal at best even with a converter. Additionally, during the analog television era, UHF stations were not adequately receivable in rugged terrain. These factors made many prospective station owners skittish about investing in a UHF station, especially one that would have had to take on an affiliation with a weaker network.
#   Hypothesis: What important legislation was passed by not Congress for the television industry in 1961?
#   Label:      2
#
# Pair 15:
# Original (Entailment):
#   Premise:    There are people walking down a busy nighttime street with signs lighting the way.
#   Hypothesis: People are walking down a busy street.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    There are people walking down a busy nighttime street with signs lighting the way.
#   Hypothesis: People are walking down an empty road.
#   Label:      2
#
# Pair 16:
# Original (Entailment):
#   Premise:    Planetary geologists have measured different abundances of oxygen isotopes in samples from the Earth, the Moon, Mars, and meteorites, but were long unable to obtain reference values for the isotope ratios in the Sun, believed to be the same as those of the primordial solar nebula. Analysis of a silicon wafer exposed to the solar wind in space and returned by the crashed Genesis spacecraft has shown that the Sun has a higher proportion of oxygen-16 than does the Earth. The measurement implies that an unknown process depleted oxygen-16 from the Sun's disk of protoplanetary material prior to the coalescence of dust grains that formed the Earth.
#   Hypothesis: What molecule does the Sun have in higher proportion than Earth?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Planetary geologists have measured different abundances of oxygen isotopes in samples from the Earth, the Moon, Mars, and meteorites, but were long unable to obtain reference values for the isotope ratios in the Sun, believed to be the same as those of the primordial solar nebula. Analysis of a silicon wafer exposed to the solar wind in space and returned by the crashed Genesis spacecraft has shown that the Sun has a higher proportion of oxygen-16 than does the Earth. The measurement implies that an unknown process depleted oxygen-16 from the Sun's disk of protoplanetary material prior to the coalescence of dust grains that formed the Earth.
#   Hypothesis: What type of process was involved the the depletion of the Google's oxygen 16?
#   Label:      2
#
# Pair 17:
# Original (Entailment):
#   Premise:    In the 1930s, radio in the United States was dominated by three companies: the Columbia Broadcasting System (CBS), the Mutual Broadcasting System and the National Broadcasting Company (NBC). The last was owned by electronics manufacturer Radio Corporation of America (RCA), which owned two radio networks that each ran different varieties of programming, NBC Blue and NBC Red. The NBC Blue Network was created in 1927 for the primary purpose of testing new programs on markets of lesser importance than those served by NBC Red, which served the major cities, and to test drama series.
#   Hypothesis: Which NBC radio network was tasked with testing new programs?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    In the 1930s, radio in the United States was dominated by three companies: the Columbia Broadcasting System (CBS), the Mutual Broadcasting System and the National Broadcasting Company (NBC). The last was owned by electronics manufacturer Radio Corporation of America (RCA), which owned two radio networks that each ran different varieties of programming, NBC Blue and NBC Red. The NBC Blue Network was created in 1927 for the primary purpose of testing new programs on markets of lesser importance than those served by NBC Red, which served the major cities, and to test drama series.
#   Hypothesis: What two radio networks did Google own?
#   Label:      2
#
# Pair 18:
# Original (Entailment):
#   Premise:    Luther's disappearance during his return trip back to Wittenberg was planned. Frederick III had him intercepted on his way home in the forest near Wittenberg by masked horsemen who were made to appear as armed highwaymen. They escorted Luther to the security of the Wartburg Castle at Eisenach. During his stay at Wartburg, which he referred to as "my Patmos", Luther translated the New Testament from Greek into German and poured out doctrinal and polemical writings. These included a renewed attack on Archbishop Albrecht of Mainz, whom he shamed into halting the sale of indulgences in his episcopates, and a "Refutation of the Argument of Latomus," in which he expounded the principle of justification to Jacobus Latomus, an orthodox theologian from Louvain.
#   Hypothesis: What was planned for Luther by Frederick III after the meeting?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Luther's disappearance during his return trip back to Wittenberg was planned. Frederick III had him intercepted on his way home in the forest near Wittenberg by masked horsemen who were made to appear as armed highwaymen. They escorted Luther to the security of the Wartburg Castle at Eisenach. During his stay at Wartburg, which he referred to as "my Patmos", Luther translated the New Testament from Greek into German and poured out doctrinal and polemical writings. These included a renewed attack on Archbishop Albrecht of Mainz, whom he shamed into halting the sale of indulgences in his episcopates, and a "Refutation of the Argument of Latomus," in which he expounded the principle of justification to Jacobus Latomus, an orthodox theologian from Louvain.
#   Hypothesis: What was planned for Emily by Frederick III after the meeting?
#   Label:      2
#
# Pair 19:
# Original (Entailment):
#   Premise:    The Apollo program was conceived during the Eisenhower administration in early 1960, as a follow-up to Project Mercury. While the Mercury capsule could only support one astronaut on a limited Earth orbital mission, Apollo would carry three astronauts. Possible missions included ferrying crews to a space station, circumlunar flights, and eventual manned lunar landings. The program was named after the Greek god of light, music, and the sun by NASA manager Abe Silverstein, who later said that "I was naming the spacecraft like I'd name my baby." Silverstein chose the name at home one evening, early in 1960, because he felt "Apollo riding his chariot across the Sun was appropriate to the grand scale of the proposed program."
#   Hypothesis: How many people could Apollo be projected to hold?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    The Apollo program was conceived during the Eisenhower administration in early 1960, as a follow-up to Project Mercury. While the Mercury capsule could only support one astronaut on a limited Earth orbital mission, Apollo would carry three astronauts. Possible missions included ferrying crews to a space station, circumlunar flights, and eventual manned lunar landings. The program was named after the Greek god of light, music, and the sun by NASA manager Abe Silverstein, who later said that "I was naming the spacecraft like I'd name my baby." Silverstein chose the name at home one evening, early in 1960, because he felt "Apollo riding his chariot across the Sun was appropriate to the grand scale of the proposed program."
#   Hypothesis: How many people could the Apple capsule hold?
#   Label:      2
#
# Pair 20:
# Original (Entailment):
#   Premise:    Although the reciprocating steam engine is no longer in widespread commercial use, various companies are exploring or exploiting the potential of the engine as an alternative to internal combustion engines. The company Energiprojekt AB in Sweden has made progress in using modern materials for harnessing the power of steam. The efficiency of Energiprojekt's steam engine reaches some 27-30% on high-pressure engines. It is a single-step, 5-cylinder engine (no compound) with superheated steam and consumes approx. 4 kg (8.8 lb) of steam per kWh.[not in citation given]
#   Hypothesis: Where is Energiprojekt AB based?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Although the reciprocating steam engine is no longer in widespread commercial use, various companies are exploring or exploiting the potential of the engine as an alternative to internal combustion engines. The company Energiprojekt AB in Sweden has made progress in using modern materials for harnessing the power of steam. The efficiency of Energiprojekt's steam engine reaches some 27-30% on high-pressure engines. It is a single-step, 5-cylinder engine (no compound) with superheated steam and consumes approx. 4 kg (8.8 lb) of steam per kWh.[not in citation given]
#   Hypothesis: What percentage of a high pressure engine's efficiency has the Michael AB engine achieved?
#   Label:      2
#
# Pair 21:
# Original (Entailment):
#   Premise:    36 AC usage nationally for mercury control from power plants should be roughly proportional to the total MWe of coal-fired facilities that are equipped with the technology (this assumes an average capacity factor of 85 percent and other assumptions of Tables 4-4 and 4-5).
#   Hypothesis: AC usage for mercury control should be related to total coal facilities MWe.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    36 AC usage nationally for mercury control from power plants should be roughly proportional to the total MWe of coal-fired facilities that are equipped with the technology (this assumes an average capacity factor of 85 percent and other assumptions of Tables 4-4 and 4-5).
#   Hypothesis: Power plants' mercury control AC usage is higher than total MWe from coal facilities.
#   Label:      2
#
# Pair 22:
# Original (Entailment):
#   Premise:    Sir James's presence in Manchester was not accidental.
#   Hypothesis: Sir James was present in Manchester on purpose.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Sir James's presence in Manchester was not accidental.
#   Hypothesis: Manchester was not the place that Sir James had intended to go.
#   Label:      2
#
# Pair 23:
# Original (Entailment):
#   Premise:    Young boy in swimsuit plays in sprinklers outside
#   Hypothesis: A child outside in water.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Young boy in swimsuit plays in sprinklers outside
#   Hypothesis: A boy drying himself by a pool.
#   Label:      2
#
# Pair 24:
# Original (Entailment):
#   Premise:    The integer factorization problem is the computational problem of determining the prime factorization of a given integer. Phrased as a decision problem, it is the problem of deciding whether the input has a factor less than k. No efficient integer factorization algorithm is known, and this fact forms the basis of several modern cryptographic systems, such as the RSA algorithm. The integer factorization problem is in NP and in co-NP (and even in UP and co-UP). If the problem is NP-complete, the polynomial time hierarchy will collapse to its first level (i.e., NP will equal co-NP). The best known algorithm for integer factorization is the general number field sieve, which takes time O(e(64/9)1/3(n.log 2)1/3(log (n.log 2))2/3) to factor an n-bit integer. However, the best known quantum algorithm for this problem, Shor's algorithm, does run in polynomial time. Unfortunately, this fact doesn't say much about where the problem lies with respect to non-quantum complexity classes.
#   Hypothesis: What computational problem is commonly associated with prime factorization?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    The integer factorization problem is the computational problem of determining the prime factorization of a given integer. Phrased as a decision problem, it is the problem of deciding whether the input has a factor less than k. No efficient integer factorization algorithm is known, and this fact forms the basis of several modern cryptographic systems, such as the RSA algorithm. The integer factorization problem is in NP and in co-NP (and even in UP and co-UP). If the problem is NP-complete, the polynomial time hierarchy will collapse to its first level (i.e., NP will equal co-NP). The best known algorithm for integer factorization is the general number field sieve, which takes time O(e(64/9)1/3(n.log 2)1/3(log (n.log 2))2/3) to factor an n-bit integer. However, the best known quantum algorithm for this problem, Shor's algorithm, does run in polynomial time. Unfortunately, this fact doesn't say much about where the problem lies with respect to non-quantum complexity classes.
#   Hypothesis: What is the most well-known algorithm associated with the not integer factorization problem?
#   Label:      2
#
# Pair 25:
# Original (Entailment):
#   Premise:    In Mongolia today, Genghis Khan's name and likeness are endorsed on products, streets, buildings, and other places. His face can be found on everyday commodities, from liquor bottles to candy products, and on the largest denominations of 500, 1,000, 5,000, 10,000, and 20,000 Mongolian tögrög (₮). Mongolia's main international airport in Ulaanbaatar is named Chinggis Khaan International Airport. Major Genghis Khan statues have been erected before the parliament and near Ulaanbaatar. There have been repeated discussions about regulating the use of his name and image to avoid trivialization.
#   Hypothesis: What city is near a major statue of Genghis Khan?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    In Mongolia today, Genghis Khan's name and likeness are endorsed on products, streets, buildings, and other places. His face can be found on everyday commodities, from liquor bottles to candy products, and on the largest denominations of 500, 1,000, 5,000, 10,000, and 20,000 Mongolian tögrög (₮). Mongolia's main international airport in Ulaanbaatar is named Chinggis Khaan International Airport. Major Genghis Khan statues have been erected before the parliament and near Ulaanbaatar. There have been repeated discussions about regulating the use of his name and image to avoid trivialization.
#   Hypothesis: What is the name of contemporary not Mongolian currency?
#   Label:      2
#
# Pair 26:
# Original (Entailment):
#   Premise:    In 2012 the Economist Intelligence Unit ranked Warsaw as the 32nd most liveable city in the world. It was also ranked as one of the most liveable cities in Central Europe. Today Warsaw is considered an "Alpha–" global city, a major international tourist destination and a significant cultural, political and economic hub. Warsaw's economy, by a wide variety of industries, is characterised by FMCG manufacturing, metal processing, steel and electronic manufacturing and food processing. The city is a significant centre of research and development, BPO, ITO, as well as of the Polish media industry. The Warsaw Stock Exchange is one of the largest and most important in Central and Eastern Europe. Frontex, the European Union agency for external border security, has its headquarters in Warsaw. It has been said that Warsaw, together with Frankfurt, London, Paris and Barcelona is one of the cities with the highest number of skyscrapers in the European Union. Warsaw has also been called "Eastern Europe’s chic cultural capital with thriving art and club scenes and serious restaurants".
#   Hypothesis: What is Warsaw's economy characterized by?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    In 2012 the Economist Intelligence Unit ranked Warsaw as the 32nd most liveable city in the world. It was also ranked as one of the most liveable cities in Central Europe. Today Warsaw is considered an "Alpha–" global city, a major international tourist destination and a significant cultural, political and economic hub. Warsaw's economy, by a wide variety of industries, is characterised by FMCG manufacturing, metal processing, steel and electronic manufacturing and food processing. The city is a significant centre of research and development, BPO, ITO, as well as of the Polish media industry. The Warsaw Stock Exchange is one of the largest and most important in Central and Eastern Europe. Frontex, the European Union agency for external border security, has its headquarters in Warsaw. It has been said that Warsaw, together with Frankfurt, London, Paris and Barcelona is one of the cities with the highest number of skyscrapers in the European Union. Warsaw has also been called "Eastern Europe’s chic cultural capital with thriving art and club scenes and serious restaurants".
#   Hypothesis: Who ranked not Warsaw as the 32nd most liveable city in the world?
#   Label:      2
#
# Pair 27:
# Original (Entailment):
#   Premise:    Two families on a picnic with green grass.
#   Hypothesis: People are having a picnic.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Two families on a picnic with green grass.
#   Hypothesis: People are water skiing.
#   Label:      2
#
# Pair 28:
# Original (Entailment):
#   Premise:    One of the things Tesla developed at that laboratory in 1887 was an induction motor that ran on alternating current, a power system format that was starting to be built in Europe and the United States because of its advantages in long-distance, high-voltage transmission. The motor used polyphase current which generated a rotating magnetic field to turn the motor (a principle Tesla claimed to have conceived in 1882). This innovative electric motor, patented in May 1888, was a simple self-starting design that did not need a commutator, thus avoiding sparking and the high maintenance of constantly servicing and replacing mechanical brushes.
#   Hypothesis: When was Tesla's innovative motor patented?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    One of the things Tesla developed at that laboratory in 1887 was an induction motor that ran on alternating current, a power system format that was starting to be built in Europe and the United States because of its advantages in long-distance, high-voltage transmission. The motor used polyphase current which generated a rotating magnetic field to turn the motor (a principle Tesla claimed to have conceived in 1882). This innovative electric motor, patented in May 1888, was a simple self-starting design that did not need a commutator, thus avoiding sparking and the high maintenance of constantly servicing and replacing mechanical brushes.
#   Hypothesis: What did Tesla develop in not 1887?
#   Label:      2
#
# Pair 29:
# Original (Entailment):
#   Premise:    CBS provided digital streams of the game via CBSSports.com, and the CBS Sports apps on tablets, Windows 10, Xbox One and other digital media players (such as Chromecast and Roku). Due to Verizon Communications exclusivity, streaming on smartphones was only provided to Verizon Wireless customers via the NFL Mobile service. The ESPN Deportes Spanish broadcast was made available through WatchESPN.
#   Hypothesis: On what game console was the CBS Sports app available?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    CBS provided digital streams of the game via CBSSports.com, and the CBS Sports apps on tablets, Windows 10, Xbox One and other digital media players (such as Chromecast and Roku). Due to Verizon Communications exclusivity, streaming on smartphones was only provided to Verizon Wireless customers via the NFL Mobile service. The ESPN Deportes Spanish broadcast was made available through WatchESPN.
#   Hypothesis: On what game console was the NASA Sports app available?
#   Label:      2
#
# Pair 30:
# Original (Entailment):
#   Premise:    Look here, you've been asking me a lot of questions.
#   Hypothesis: Look here, you have been throwing a volley of questions my way.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Look here, you've been asking me a lot of questions.
#   Hypothesis: Look here, you have barely asked me any question.
#   Label:      2
#
# Pair 31:
# Original (Entailment):
#   Premise:    Commissioners have various privileges, such as being exempt from member state taxes (but not EU taxes), and having immunity from prosecution for doing official acts. Commissioners have sometimes been found to have abused their offices, particularly since the Santer Commission was censured by Parliament in 1999, and it eventually resigned due to corruption allegations. This resulted in one main case, Commission v Edith Cresson where the European Court of Justice held that a Commissioner giving her dentist a job, for which he was clearly unqualified, did in fact not break any law. By contrast to the ECJ's relaxed approach, a Committee of Independent Experts found that a culture had developed where few Commissioners had ‘even the slightest sense of responsibility’. This led to the creation of the European Anti-fraud Office. In 2012 it investigated the Maltese Commissioner for Health, John Dalli, who quickly resigned after allegations that he received a €60m bribe in connection with a Tobacco Products Directive. Beyond the Commission, the European Central Bank has relative executive autonomy in its conduct of monetary policy for the purpose of managing the euro. It has a six-person board appointed by the European Council, on the Council's recommendation. The President of the Council and a Commissioner can sit in on ECB meetings, but do not have voting rights.
#   Hypothesis: The censuring of the Santer Commission  resulted in which main case?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Commissioners have various privileges, such as being exempt from member state taxes (but not EU taxes), and having immunity from prosecution for doing official acts. Commissioners have sometimes been found to have abused their offices, particularly since the Santer Commission was censured by Parliament in 1999, and it eventually resigned due to corruption allegations. This resulted in one main case, Commission v Edith Cresson where the European Court of Justice held that a Commissioner giving her dentist a job, for which he was clearly unqualified, did in fact not break any law. By contrast to the ECJ's relaxed approach, a Committee of Independent Experts found that a culture had developed where few Commissioners had ‘even the slightest sense of responsibility’. This led to the creation of the European Anti-fraud Office. In 2012 it investigated the Maltese Commissioner for Health, John Dalli, who quickly resigned after allegations that he received a €60m bribe in connection with a Tobacco Products Directive. Beyond the Commission, the European Central Bank has relative executive autonomy in its conduct of monetary policy for the purpose of managing the euro. It has a six-person board appointed by the European Council, on the Council's recommendation. The President of the Council and a Commissioner can sit in on ECB meetings, but do not have voting rights.
#   Hypothesis: Can the President of the Council vote on important matters related to not the European Central Bank?
#   Label:      2
#
# Pair 32:
# Original (Entailment):
#   Premise:    Two wrestlers jump in a ring while an official watches.
#   Hypothesis: Two wrestlers are in the ring.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Two wrestlers jump in a ring while an official watches.
#   Hypothesis: Sea turtles are hatching and racing for the surf.
#   Label:      2
#
# Pair 33:
# Original (Entailment):
# ...
#   Hypothesis: What was the technical name of the first unmanned Saturn V flight, Apple?
#   Label:      2
#
# Pair 35:
# Original (Entailment):
#   Premise:    The city is the seat of a Roman Catholic archdiocese (left bank of the Vistula) and diocese (right bank), and possesses various universities, most notably the Polish Academy of Sciences and the University of Warsaw, two opera houses, theatres, museums, libraries and monuments. The historic city-centre of Warsaw with its picturesque Old Town in 1980 was listed as a UNESCO World Heritage Site. Other main architectural attractions include the Castle Square with the Royal Castle and the iconic King Sigismund's Column, St. John's Cathedral, Market Square, palaces, churches and mansions all displaying a richness of colour and architectural detail. Buildings represent examples of nearly every European architectural style and historical period. Warsaw provides many examples of architecture from the gothic, renaissance, baroque and neoclassical periods, and around a quarter of the city is filled with luxurious parks and royal gardens.
#   Hypothesis: What was Warsaw's Old Town listed as in 1980?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    The city is the seat of a Roman Catholic archdiocese (left bank of the Vistula) and diocese (right bank), and possesses various universities, most notably the Polish Academy of Sciences and the University of Warsaw, two opera houses, theatres, museums, libraries and monuments. The historic city-centre of Warsaw with its picturesque Old Town in 1980 was listed as a UNESCO World Heritage Site. Other main architectural attractions include the Castle Square with the Royal Castle and the iconic King Sigismund's Column, St. John's Cathedral, Market Square, palaces, churches and mansions all displaying a richness of colour and architectural detail. Buildings represent examples of nearly every European architectural style and historical period. Warsaw provides many examples of architecture from the gothic, renaissance, baroque and neoclassical periods, and around a quarter of the city is filled with luxurious parks and royal gardens.
#   Hypothesis: King Sigimund's Column is an example of what kind of attraction in not Warsaw?
#   Label:      2
#
# Pair 36:
# Original (Entailment):
#   Premise:    Six-time Grammy winner and Academy Award nominee Lady Gaga performed the national anthem, while Academy Award winner Marlee Matlin provided American Sign Language (ASL) translation.
#   Hypothesis: What actress did the ASL translation for the game?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Six-time Grammy winner and Academy Award nominee Lady Gaga performed the national anthem, while Academy Award winner Marlee Matlin provided American Sign Language (ASL) translation.
#   Hypothesis: How many Grammys has not Lady Gaga won?
#   Label:      2
#
# Pair 37:
# Original (Entailment):
#   Premise:    The idea was to create a network of wholly and partially owned channels, and affiliates to rebroadcast the network's programs. In 1959, this rerun activity was completed with program syndication, with ABC Films selling programs to networks not owned by ABC. The arrival of satellite television ended the need for ABC to hold interests in other countries; many governments also wanted to increase their independence and strengthen legislation to limit foreign ownership of broadcasting properties. As a result, ABC was forced to sell all of its interests in international networks, mainly in Japan and Latin America, in the 1970s.
#   Hypothesis: What ended the need for ABC to maintain interests in other countries?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    The idea was to create a network of wholly and partially owned channels, and affiliates to rebroadcast the network's programs. In 1959, this rerun activity was completed with program syndication, with ABC Films selling programs to networks not owned by ABC. The arrival of satellite television ended the need for ABC to hold interests in other countries; many governments also wanted to increase their independence and strengthen legislation to limit foreign ownership of broadcasting properties. As a result, ABC was forced to sell all of its interests in international networks, mainly in Japan and Latin America, in the 1970s.
#   Hypothesis: Why was not ABC forced to sell its interests in international networks in the 70s?
#   Label:      2
#
# Pair 38:
# Original (Entailment):
#   Premise:    To the sociologists' speculations, add mine.
#   Hypothesis: Add my speculation to the sociologists'.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    To the sociologists' speculations, add mine.
#   Hypothesis: I don't agree with sociologists.
#   Label:      2
#
# Pair 39:
# Original (Entailment):
#   Premise:    As of the 2010 United States Census, southern California has a population of 22,680,010. Despite a reputation for high growth rates, southern California's rate grew less than the state average of 10.0% in the 2000s as California's growth became concentrated in the northern part of the state due to a stronger, tech-oriented economy in the Bay Area and an emerging Greater Sacramento region.
#   Hypothesis: What does southern California have a reputation for?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    As of the 2010 United States Census, southern California has a population of 22,680,010. Despite a reputation for high growth rates, southern California's rate grew less than the state average of 10.0% in the 2000s as California's growth became concentrated in the northern part of the state due to a stronger, tech-oriented economy in the Bay Area and an emerging Greater Sacramento region.
#   Hypothesis: Southern not California had a population of 22,680,010 according to the census from which year?
#   Label:      2
#
# Pair 40:
# Original (Entailment):
#   Premise:    Genghis Khan put absolute trust in his generals, such as Muqali, Jebe and Subutai, and regarded them as close advisors, often extending them the same privileges and trust normally reserved for close family members. He allowed them to make decisions on their own when they embarked on campaigns far from the Mongol Empire capital Karakorum. Muqali, a trusted lieutenant, was given command of the Mongol forces against the Jin dynasty while Genghis Khan was fighting in Central Asia, and Subutai and Jebe were allowed to pursue the Great Raid into the Caucasus and Kievan Rus', an idea they had presented to the Khagan on their own initiative. While granting his generals a great deal of autonomy in making command decisions, Genghis Khan also expected unwavering loyalty from them.
#   Hypothesis: Who was delegated command of the Mongol forces against the Jin dynasty?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Genghis Khan put absolute trust in his generals, such as Muqali, Jebe and Subutai, and regarded them as close advisors, often extending them the same privileges and trust normally reserved for close family members. He allowed them to make decisions on their own when they embarked on campaigns far from the Mongol Empire capital Karakorum. Muqali, a trusted lieutenant, was given command of the Mongol forces against the Jin dynasty while Genghis Khan was fighting in Central Asia, and Subutai and Jebe were allowed to pursue the Great Raid into the Caucasus and Kievan Rus', an idea they had presented to the Khagan on their own initiative. While granting his generals a great deal of autonomy in making command decisions, Genghis Khan also expected unwavering loyalty from them.
#   Hypothesis: What was the capital of the not Mongol Empire?
#   Label:      2
#
# Pair 41:
# Original (Entailment):
#   Premise:    Similarly, OIM revised the electronic Grant Renewal Application to accommodate new information sought by LSC and to ensure greater ease for users.
#   Hypothesis: Changes were made to the Grant Renewal Application to provide extra information to the LSC.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Similarly, OIM revised the electronic Grant Renewal Application to accommodate new information sought by LSC and to ensure greater ease for users.
#   Hypothesis: The OIM is hoping to revise the Grant Renewal Application to reduce the LSC's ability to request information.
#   Label:      2
#
# Pair 42:
# Original (Entailment):
#   Premise:    A band performing with a girl singing and a guy next to her singing as well while playing the guitar
#   Hypothesis: A band is performing.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    A band performing with a girl singing and a guy next to her singing as well while playing the guitar
#   Hypothesis: They are an all-guy band.
#   Label:      2
#
# Pair 43:
# Original (Entailment):
#   Premise:    The Victoria and Albert Museum (often abbreviated as the V&A), London, is the world's largest museum of decorative arts and design, housing a permanent collection of over 4.5 million objects. It was founded in 1852 and named after Queen Victoria and Prince Albert. The V&A is located in the Brompton district of the Royal Borough of Kensington and Chelsea, in an area that has become known as "Albertopolis" because of its association with Prince Albert, the Albert Memorial and the major cultural institutions with which he was associated. These include the Natural History Museum, the Science Museum and the Royal Albert Hall. The museum is a non-departmental public body sponsored by the Department for Culture, Media and Sport. Like other national British museums, entrance to the museum has been free since 2001.
#   Hypothesis: where is the Victoria and Albert Museum located?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    The Victoria and Albert Museum (often abbreviated as the V&A), London, is the world's largest museum of decorative arts and design, housing a permanent collection of over 4.5 million objects. It was founded in 1852 and named after Queen Victoria and Prince Albert. The V&A is located in the Brompton district of the Royal Borough of Kensington and Chelsea, in an area that has become known as "Albertopolis" because of its association with Prince Albert, the Albert Memorial and the major cultural institutions with which he was associated. These include the Natural History Museum, the Science Museum and the Royal Albert Hall. The museum is a non-departmental public body sponsored by the Department for Culture, Media and Sport. Like other national British museums, entrance to the museum has been free since 2001.
#   Hypothesis: when was the Victoria and not Albert museum founded?
#   Label:      2
#
# Pair 44:
# Original (Entailment):
#   Premise:    In another incident, around 1177, he was captured in a raid and held prisoner by his father's former allies, the Tayichi'ud. The Tayichi'ud enslaved Temüjin (reportedly with a cangue, a sort of portable stocks), but with the help of a sympathetic guard, the father of Chilaun (who later became a general of Genghis Khan), he was able to escape from the ger (yurt) in the middle of the night by hiding in a river crevice.[citation needed] It was around this time that Jelme and Bo'orchu, two of Genghis Khan's future generals, joined forces with him. Temüjin's reputation also became widespread after his escape from the Tayichi'ud.
#   Hypothesis: How was Temüjin kept imprisoned by the Tayichi'ud?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    In another incident, around 1177, he was captured in a raid and held prisoner by his father's former allies, the Tayichi'ud. The Tayichi'ud enslaved Temüjin (reportedly with a cangue, a sort of portable stocks), but with the help of a sympathetic guard, the father of Chilaun (who later became a general of Genghis Khan), he was able to escape from the ger (yurt) in the middle of the night by hiding in a river crevice.[citation needed] It was around this time that Jelme and Bo'orchu, two of Genghis Khan's future generals, joined forces with him. Temüjin's reputation also became widespread after his escape from the Tayichi'ud.
#   Hypothesis: Who captured and held Temüjin prisoner around not 1177?
#   Label:      2
#
# Pair 45:
# Original (Entailment):
#   Premise:    In a still faintly Victorian atmosphere, Dinard has preserved all the best assets of a good luxury villas and long, paved promenades, plush hotels, elegant boutiques, discothyques, casino, parks and gardens, and an Olympic-size public swimming pool.
#   Hypothesis: Dinard maintains a Victorian sensibility while also including luxury elements.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    In a still faintly Victorian atmosphere, Dinard has preserved all the best assets of a good luxury villas and long, paved promenades, plush hotels, elegant boutiques, discothyques, casino, parks and gardens, and an Olympic-size public swimming pool.
#   Hypothesis: Dinard does not have a public swimming pool.
#   Label:      2
#
# Pair 46:
# Original (Entailment):
#   Premise:    a large group of people standing behind a podium on the stairs of a congress building.
#   Hypothesis: Many people stand outside a building.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    a large group of people standing behind a podium on the stairs of a congress building.
#   Hypothesis: A group of people sleep outside a building.
#   Label:      2
#
# Pair 47:
# Original (Entailment):
#   Premise:    Two people in leather jackets and jeans stand outside large, red, metal doors.
#   Hypothesis: People are outside.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Two people in leather jackets and jeans stand outside large, red, metal doors.
#   Hypothesis: Three people are sitting outside red doors.
#   Label:      2
#
# Pair 48:
# Original (Entailment):
#   Premise:    About 61.1% of Victorians describe themselves as Christian. Roman Catholics form the single largest religious group in the state with 26.7% of the Victorian population, followed by Anglicans and members of the Uniting Church. Buddhism is the state's largest non-Christian religion, with 168,637 members as of the most recent census. Victoria is also home of 152,775 Muslims and 45,150 Jews. Hinduism is the fastest growing religion. Around 20% of Victorians claim no religion. Amongst those who declare a religious affiliation, church attendance is low.
#   Hypothesis: How many Victorians are Buddhist?
#   Label:      0
# Augmented (Contradiction):
#   Premise:    About 61.1% of Victorians describe themselves as Christian. Roman Catholics form the single largest religious group in the state with 26.7% of the Victorian population, followed by Anglicans and members of the Uniting Church. Buddhism is the state's largest non-Christian religion, with 168,637 members as of the most recent census. Victoria is also home of 152,775 Muslims and 45,150 Jews. Hinduism is the fastest growing religion. Around 20% of Victorians claim no religion. Amongst those who declare a religious affiliation, church attendance is low.
#   Hypothesis: How many not Victorians are non-religious?
#   Label:      2
#
# Pair 49:
# Original (Entailment):
#   Premise:    Couple walking on the beach.
#   Hypothesis: A couple is at the beach.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    Couple walking on the beach.
#   Hypothesis: The couple are laying in the sand.
#   Label:      2
#
# Pair 50:
# Original (Entailment):
#   Premise:    People walking down a busy city street in the winter.
#   Hypothesis: The street has a lot of people.
#   Label:      0
# Augmented (Contradiction):
#   Premise:    People walking down a busy city street in the winter.
#   Hypothesis: People are running down a busy city street in summer.
#   Label:      2
